# %% [markdown]
# ## Part 2: Information Extraction using NLTK
#
# [NLTK](http://www.nltk.org/) is a python platform for natural language processing and information extraction. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, and an active discussion forum.
#
# The associated book, [Natural Language Processing with Python](http://www.nltk.org/book/) is also freely available and is a great resource both for NLP concepts and for practical examples of how to use the NLTK package.
#
# To get started, you need to install NLTK:
#
#     sudo pip install -U nltk
#
# After running the first command below (download()), you will be presented with a window to select which 'data' to download. For space reasons, only download 'book' (Everything used in the NLTK book). This in itself is a few hundred MB download.

# %%
import nltk
nltk.download()
# Out:
# showing info http://nltk.github.com/nltk_data/
# True

# %%
# Test it is working

sentence = """At eight o'clock on Thursday morning, Arthur didn't feel very good."""
tokens = nltk.word_tokenize(sentence)
tagged = nltk.pos_tag(tokens)
tagged
# Out:
# [('At', 'IN'),
#  ('eight', 'CD'),
#  ("o'clock", 'JJ'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('morning', 'NN'),
#  (',', ','),
#  ('Arthur', 'NNP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('feel', 'VB'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.')]

# %% [markdown]
# The above two commands tokenize the string, and tag each of the token with the part-of-speech. Here is a listing of tagsets that NLTK uses here (there are different tagsets used by different corpora).
# http://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %% [markdown]
# The following set of commands extracts named entities.

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities
# Out:
# Tree('S', [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'JJ'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), (',', ','), Tree('PERSON', [('Arthur', 'NNP')]), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')])

# %%
# Visual representation of the tree 
entities.draw()

# %% [markdown]
# ###Named Entity Recognition
#
# As a somewhat more elaborate example, the following sequence of commands reads data from a file, and does NER on each of the sentences in the file. It doesn't do a very good job on this article, but in general, it seems to work quite well.

# %%
with open("news1.html", "r") as myfile:
    data = myfile.read()   
sentences = nltk.sent_tokenize(data)
sentences = [nltk.word_tokenize(sent) for sent in sentences]
sentences = [nltk.pos_tag(sent) for sent in sentences]
print(nltk.ne_chunk(sentences[0]))
# Out:
# (S
#   CDC/NNP
#   considers/NNS
#   adding/VBG
#   names/NNS
#   of/IN
#   health/NN
#   workers/NNS
#   monitored/VBD
#   for/IN
#   (PERSON Ebola/NNP)
#   to/TO
#   no-fly/NNP
#   list/NN
#   (PERSON Published/NNP)
#   October/NNP
#   16/CD
#   ,/,
#   2014/CD
#   FoxNews.com/JJ
#   </NN
#   http/NN
#   :/:
#   //www.foxnews.com//JJ
#   >/NN
#   (PERSON Facebook/NNP)
#   </NNP
#   #/#
#   >/:
#   558/CD
#   Twitter/NNP
#   </NNP
#   #/#
#   >/:
#   597/CD
#   livefyre/NN
#   </:
#   #/#
#   >/:
#   1623/CD
#   Email/NNP
#   </NNP
#   #/#
#   >/:
#   Print/NNP
#   </:
#   #/#
#   >/:
#   Now/NNP
#   Playing/NNP
#   CDC/NNP
#   :/:
#   Second/NNP
#   (PERSON Dallas/NNP Ebola/NNP)
#   patient/NN
#   took/VBD
#   commercial/JJ
#   flight/NN
#   Never/RB
#   autoplay/NN
#   videos/NNS
#   </:
#   #/#
#   >/:
#   The/DT
#   (ORGANIZATION Centers/NNPS)
#   for/IN
#   (PERSON Disease/NNP Control/NNP)
#   and/CC
#   Prevention/NNP
#   is/VBZ
#   considering/VBG
#   adding/VBG
#   the/DT
#   names/NNS
#   of/IN
#   healthcare/NN
#   workers/NNS
#   being/VBG
#   monitored/VBN
#   for/IN
#   the/DT
#   (ORGANIZATION Ebola/NNP)
#   virus/VBZ
#   to/TO
#   the/DT
#   government/NN
#   's/POS
#   no-fly/JJ
#   list/NN
#   ,/,
#   federal/JJ
#   officials/NNS
#   tell/VBP
#   (PERSON Fox/NNP News/NNP)
#   ./.)

# %% [markdown]
# ### Relation Extraction
#
# The second key task is to extract relations between entities. The following code snippet finds the relations between organizations and locations, in one of the existing datasets in NLTK. See the book webpage for more details on the regular expression pattern below: http://www.nltk.org/book/ch07.html

# %%
import re
IN = re.compile(r'.*\bin\b(?!\b.+ing)')
for doc in nltk.corpus.ieer.parsed_docs('NYT_19980315'):
    for rel in nltk.sem.extract_rels('ORG', 'LOC', doc, corpus='ieer', pattern = IN):
        print(nltk.sem.rtuple(rel))
# Out:
# [ORG: u'WHYY'] u'in' [LOC: u'Philadelphia']
# [ORG: u'McGlashan &AMP; Sarrail'] u'firm in' [LOC: u'San Mateo']
# [ORG: u'Freedom Forum'] u'in' [LOC: u'Arlington']
# [ORG: u'Brookings Institution'] u', the research group in' [LOC: u'Washington']
# [ORG: u'Idealab'] u', a self-described business incubator based in' [LOC: u'Los Angeles']
# [ORG: u'Open Text'] u', based in' [LOC: u'Waterloo']
# [ORG: u'WGBH'] u'in' [LOC: u'Boston']
# [ORG: u'Bastille Opera'] u'in' [LOC: u'Paris']
# [ORG: u'Omnicom'] u'in' [LOC: u'New York']
# [ORG: u'DDB Needham'] u'in' [LOC: u'New York']
# [ORG: u'Kaplan Thaler Group'] u'in' [LOC: u'New York']
# [ORG: u'BBDO South'] u'in' [LOC: u'Atlanta']
# [ORG: u'Georgia-Pacific'] u'in' [LOC: u'Atlanta']

# %% [markdown]
# ### Assignment
#
# **PART 2.1 (NER):** Download, say 10 recent news articles, on some topic. Write code to extract named entities from each of them. The final output should simply be a list of entities and their types, which would require understanding the structure of the output of the ne_chunk command, and traversing it to find just the named entities.
#
# Submit both the python code, and the entities you extracted. For example, for the article above, the output should be:
#
#     Ebola, PERSON
#     Published, PERSON
#     Facebook, PERSON
#     ...
#
# **Part 2.2 (Relation Extraction):** Write a few regular expressions to extract different types of PERSON-ORGANIZATION relationships (e.g., PERSON executive at ORGANIZATION) over the same dataset (the IEER Corpus). You can use the above script mostly unchanged with the changes being: definition of the pattern IN, and the arguments to `extract_rels`.
#
# It may be useful to see the text of some of the documents, e.g., the second document in the above corpus can be seen by running:
#
#     print(nltk.corpus.ieer.parsed_docs('NYT_19980315')[1].text)

# %% [markdown]
# # Part 2.1 (NER)

# %%
for num in range(1,9):
    article = "news/news0" + str(num) + ".html"
    with open(article, "r") as myfile:
        data = ""
        data = myfile.read() 
        data = data.decode('utf-8')

    sentences = nltk.sent_tokenize(data)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    

    chunks = [nltk.ne_chunk(sent) for sent in sentences]
    
    print "Article", num

    # ORGANIZATION	Georgia-Pacific Corp., WHO
    # PERSON	Eddy Bonte, President Obama
    # LOCATION	Murray River, Mount Everest
    # DATE	June, 2008-06-29
    # TIME	two fifty a m, 1:30 p.m.
    # MONEY	175 million Canadian Dollars, GBP 10.40
    # PERCENT	twenty pct, 18.75 %
    # FACILITY	Washington Monument, Stonehenge
    # GPE	South East Asia, Midlothian
    
    for smallchunk in chunks:
        for chunk in smallchunk:
            if isinstance(chunk, nltk.tree.Tree):  
                if chunk.label() == 'PERSON':
                    person = ""
                    for i in chunk.leaves():
                        person += i[0] + " "
                    print person[:-1] + ", " + "PERSON"
                elif chunk.label() == 'ORGANIZATION':
                    org = ""
                    for i in chunk.leaves():
                        org += i[0] + " "
                    print org[:-1] + ", " + "ORGANIZATION"
                elif chunk.label() == 'GPE':
                    gpe = ""
                    for i in chunk.leaves():
                        gpe += i[0] + " "
                    print gpe[:-1] + ", " + "GPE"
                elif chunk.label() == 'FACILITY':
                    facility = ""
                    for i in chunk.leaves():
                        facility += i[0] + " "
                    print facility[:-1] + ", " + "FACILITY"
                elif chunk.label() == 'LOCATION':
                    location = ""
                    for i in chunk.leaves():
                        location += i[0] + " "
                    print location[:-1] + ", " + "LOCATION"
                elif chunk.label() == 'PERCENT':
                    percent = ""
                    for i in chunk.leaves():
                        percent += i[0] + " "
                    print percent[:-1] + ", " + "PERCENT"
                elif chunk.label() == 'TIME':
                    time = ""
                    for i in chunk.leaves():
                        time += i[0] + " "
                    print time[:-1] + ", " + "TIME"
                elif chunk.label() == 'DATE':
                    date = ""
                    for i in chunk.leaves():
                        date += i[0] + " "
                    print date[:-1] + ", " + "DATE"
                elif chunk.label() == 'MONEY':
                    money = ""
                    for i in chunk.leaves():
                        money += i[0] + " "
                    print money[:-1] + ", " + "MONEY"             
    print
# Out:
# Article 1
# U.S., GPE
# Africa, GPE
# American, GPE
# Liberia, GPE
# Operation United Assistance, ORGANIZATION
# U.S., GPE
# Ebola, ORGANIZATION
# U.S., GPE
# Leopold Sedar Senghor International Airport, ORGANIZATION
# Dakar, GPE
# Senegal, GPE
# U.S., GPE
# Air National Guard, ORGANIZATION
# Dale, PERSON
# Joel Achenbach, PERSON
# Lena H. Sun, PERSON
# Americans, GPE
# Liberia, GPE
# U.S., GPE
# United, PERSON
# Sgt, PERSON
# John Kolodgy, PERSON
# Fort Bliss, ORGANIZATION
# Liberia, GPE
# Ebola, PERSON
# Ebola, GPE
# Fort Bliss, ORGANIZATION
# El Paso, GPE
# Campbell, PERSON
# U.S., GPE
# West Africa, LOCATION
# Global, GPE
# Ebola, GPE
# ETUs, ORGANIZATION
# Liberia, GPE
# Ebola, PERSON
# West Africa, LOCATION
# View, PERSON
# Ebola, PERSON
# West Africa, LOCATION
# Past, GPE
# U.S., GPE
# Liberia, GPE
# U.S., GPE
# Guinea, PERSON
# Sierra Leone, PERSON
# West Africa, LOCATION
# Obama, PERSON
# World, ORGANIZATION
# Mali, GPE
# Guinea, GPE
# Ebola, GPE
# WHO, ORGANIZATION
# Lancet, ORGANIZATION
# Liberia, GPE
# U.S., GPE
# Ebola, ORGANIZATION
# U.S., GPE
# ETUs, ORGANIZATION
# Ebola, GPE
# Pentagon, FACILITY
# Pentagon, FACILITY
# U.S., GPE
# International Development, ORGANIZATION
# West Africa, LOCATION
# USAID, ORGANIZATION
# International Medical Corps, ORGANIZATION
# Children, GPE
# International Organization, ORGANIZATION
# Migration, ORGANIZATION
# International Rescue Committee, ORGANIZATION
# Ebola, PERSON
# New York, GPE
# New Jersey, GPE
# Illinois, PERSON
# West Africa, LOCATION
# Ebola, PERSON
# West Africa, LOCATION
# Ebola, ORGANIZATION
# Monrovia, GPE
# Abbas, PERSON
# Kaci Hickox, PERSON
# Doctors Without Borders, PERSON
# New Jersey, GPE
# Ebola, PERSON
# Dallas, ORGANIZATION
# U.S., GPE
# Monrovia, GPE
# Liberian, GPE
# Public Health Service, ORGANIZATION
# Department, ORGANIZATION
# Health, GPE
# Human Services, ORGANIZATION
# Coast Guard, ORGANIZATION
# PHS, ORGANIZATION
# Ellis Island, FACILITY
# Iraq, GPE
# Afghanistan, GPE
# Monrovia, GPE
# HHS, ORGANIZATION
# Capt, PERSON
# Calvin, PERSON
# Edwards, ORGANIZATION
# PHS, ORGANIZATION
# Liberia, GPE
# Food, ORGANIZATION
# Drug Administration, PERSON
# Harrisburg, GPE
# Married, PERSON
# Alabama, GPE
# LongHorn Steakhouse, ORGANIZATION
# Edwards, PERSON
# New, ORGANIZATION
# Liberia, GPE
# U.S., GPE
# PPE, ORGANIZATION
# Rear, PERSON
# Scott Giberson, PERSON
# Monrovia, GPE
# Anthony Tranchita, PERSON
# PHS, ORGANIZATION
# North, GPE
# Tranchita, PERSON
# Greg, GPE
# Raczniak, PERSON
# Centers, ORGANIZATION
# Disease Control, PERSON
# West Africa, LOCATION
# Raczniak, PERSON
# Liberia, GPE
# Forts Campbell, ORGANIZATION
# Bliss, GPE
# Hood, GPE
# Carson, PERSON
# Benning, GPE
# Aberdeen, ORGANIZATION
# Jasmine, PERSON
# Holmes, ORGANIZATION
# Engineer Brigade, ORGANIZATION
# Fort Hood, ORGANIZATION
# American, GPE
# Ebola, ORGANIZATION
# West Africa, LOCATION
# CDC, ORGANIZATION
# U.S., GPE
# Greg Thorne, GPE
# CDC, ORGANIZATION
# Liberia, GPE
# Peace Corps Director Carrie, PERSON
# American, GPE
# Gbarpolu, GPE
# CDC, ORGANIZATION
# Gbarpolu, PERSON
# Thorne, PERSON
# Peace Corps, ORGANIZATION
# English, GPE
# CDC, ORGANIZATION
# Liberian, GPE
# Samuel Sampson, PERSON
# Liberian, GPE
# Peace, ORGANIZATION
# Sampson, PERSON
# George Karneh, PERSON
# Liberian, GPE
# Peace Corps, ORGANIZATION
# CDC, ORGANIZATION
# Ebola, ORGANIZATION
# Karneh, PERSON
# West Africa, LOCATION
# CDC, ORGANIZATION
# Katie Curran, PERSON
# Atlanta, PERSON
# Sierra Leone, PERSON
# Pittsburgh Steelers, ORGANIZATION
# Curran, PERSON
# West Africa, LOCATION
# Ebola, GPE
# Curran, PERSON
# U.S., GPE
# Brady Dennis, PERSON
# Alice Crites, ORGANIZATION
# Joel, PERSON
# Achenbach, PERSON
# Post, ORGANIZATION
# Lena, PERSON
# Washington Post, ORGANIZATION
#
# Article
#  2
# Ebola, PERSON
# Washington, GPE
# New York, GPE
# Andrew, PERSON
# Cuomo, GPE
# New, GPE
# Jersey Gov, PERSON
# Chris Christie, PERSON
# United States, GPE
# West Africa, LOCATION
# Mark, PERSON
# Spencer S. Hsu, PERSON
# Henderson, PERSON
# New York, GPE
# New Jersey, GPE
# Illinois, PERSON
# West Africa, LOCATION
# District, GPE
# Maryland, GPE
# Virginia, PERSON
# Health, GPE
# Joxel, PERSON
# Garcia, ORGANIZATION
# D.C. Department, ORGANIZATION
# Health, GPE
# Ebola, GPE
# New York, GPE
# New, GPE
# Jersey, PERSON
# Ebola, ORGANIZATION
# Newark Liberty International Airport, ORGANIZATION
# Dallas, ORGANIZATION
# Ebola, PERSON
# West Africa, LOCATION
# Kaci Hickox, PERSON
# Doctors Without Borders, PERSON
# U.S., GPE
# VIEW, ORGANIZATION
# Borders, PERSON
# Hickox, PERSON
# Lawrence, GPE
# Gostin, PERSON
# Georgetown University Law School, ORGANIZATION
# World, ORGANIZATION
# Sierra Leone, GPE
# Guinea, PERSON
# Liberia, GPE
# Gostin, PERSON
# Ebola, GPE
# Ebola, PERSON
# United States, GPE
# U.S., GPE
# Disease Control, PERSON
# U.S., GPE
# West African, LOCATION
# Ebola, PERSON
# New, GPE
# John F. Kennedy, PERSON
# New, GPE
# Washington Dulles, GPE
# Atlanta, PERSON
# New York, GPE
# Craig Spencer, PERSON
# Ebola, ORGANIZATION
# Spencer, PERSON
# New York, GPE
# Andrew, PERSON
# New, GPE
# Jersey Gov, PERSON
# Chris, PERSON
# Christie, ORGANIZATION
# Illinois Gov, PERSON
# Pat, PERSON
# Quinn, ORGANIZATION
# Quinn, PERSON
# Washington, GPE
# Ebola, GPE
# Garcia, PERSON
# Virginia, GPE
# Maryland, GPE
# David H. Trump, PERSON
# Virginia Department, ORGANIZATION
# Health, GPE
# Joshua M. Sharfstein, PERSON
# Maryland, GPE
# CDC, ORGANIZATION
# Barbara Reynolds, PERSON
# CDC, ORGANIZATION
# American, GPE
# BioFire, ORGANIZATION
# Ebola, PERSON
# Lena, PERSON
# Lori Aratani, PERSON
# DeNeen, ORGANIZATION
# Brown, PERSON
# Spencer S. Hsu, PERSON
#
# Article
#  3
# N.Y., GPE
# Ray Sanchez, PERSON
# Elizabeth Cohen, PERSON
# CNN, ORGANIZATION
# Sat, PERSON
# CNN, ORGANIZATION
# Borders, ORGANIZATION
# Newark Liberty International Airport, ORGANIZATION
# Ebola, GPE
# New York, GPE
# CNN, ORGANIZATION
# New York, GPE
# New Jersey, GPE
# West Africa, LOCATION
# Ebola, GPE
# New York, GPE
# New Jersey, GPE
# Andrew Cuomo, PERSON
# Chris Christie, PERSON
# New York, GPE
# Guinea, GPE
# Ebola, PERSON
# United States, GPE
# Centers, ORGANIZATION
# Disease, ORGANIZATION
# Control, ORGANIZATION
# Atlanta, GPE
# CDC, ORGANIZATION
# Ebola, ORGANIZATION
# Health, GPE
# Ebola NY, PERSON
# Ebola, PERSON
# NYC, ORGANIZATION
# Ebola Photos, PERSON
# Ebola, ORGANIZATION
# Ebola, ORGANIZATION
# New York City, GPE
# Quarantined, GPE
# Cuomo, GPE
# Christie, PERSON
# CDC, ORGANIZATION
# CDC, ORGANIZATION
# American, GPE
# CDC, ORGANIZATION
# Nurse, PERSON
# Kaci Hickox, PERSON
# Newark Liberty International Airport, ORGANIZATION
# New Jersey, GPE
# Borders, GPE
# Sierra Leone, GPE
# Hickox, GPE
# Dallas, ORGANIZATION
# Ebola, PERSON
# Hickox, PERSON
# Hickox, GPE
# Ebola, PERSON
# Dallas, GPE
# CDC, ORGANIZATION
# Doctors Without Borders, PERSON
# Medecins Sans Frontieres, ORGANIZATION
# MSF, ORGANIZATION
# New York, GPE
# New Jersey, GPE
# MSF, ORGANIZATION
# Ebola, ORGANIZATION
# West Africa, LOCATION
# New York City, GPE
# Bassett, PERSON
# Ebola, GPE
# West Africa, LOCATION
# West Africa, LOCATION
# Jean Weinberg, PERSON
# Ebola, PERSON
# Ebola, PERSON
# Cuomo, PERSON
# New, GPE
# United States, GPE
# U.S., GPE
# New York, GPE
# Kennedy, PERSON
# Dulles International, PERSON
# New Jersey, GPE
# Newark Liberty International, ORGANIZATION
# Chicago, GPE
# International, ORGANIZATION
# Hartsfield-Jackson International, ORGANIZATION
# Atlanta, GPE
# Ebola, GPE
# Liberia, GPE
# Sierra Leone, PERSON
# Guinea, GPE
# Ebola, PERSON
# National Institutes, ORGANIZATION
# Health, PERSON
# Nina Pham, PERSON
# Dallas, GPE
# Ebola, ORGANIZATION
# Public, GPE
# Ebola, PERSON
# Ebola, ORGANIZATION
# New York Ebola, GPE
# New York, GPE
# Guinea, GPE
# Ebola, GPE
# Manhattan, GPE
# Craig Spencer, PERSON
# Bellevue Hospital, ORGANIZATION
# Guinea, GPE
# Spencer, GPE
# Bellevue, ORGANIZATION
# Jean Weinberg, PERSON
# Spencer, PERSON
# Manhattan, GPE
# Spencer, GPE
# West African, GPE
# The Gutter, ORGANIZATION
# Brooklyn, GPE
# New York, GPE
# Bill, PERSON
# Blasio, PERSON
# Manhattan, GPE
# American, GPE
# United States, GPE
# U.S., GPE
# Andy Harris, PERSON
# Ebola, GPE
# Maryland Republican, ORGANIZATION
# CNN, ORGANIZATION
# Ebola, GPE
# United States, GPE
# American, GPE
# Africa, GPE
# Blasio, PERSON
#
# Article
#  4
# Mali, PERSON
# ADAM, ORGANIZATION
# Senegal, ORGANIZATION
# Ebola, PERSON
# Malian, GPE
# World, ORGANIZATION
# Guinea, GPE
# Mali, GPE
# Mali, GPE
# West African, LOCATION
# Mali, GPE
# RELATED, ORGANIZATION
# Ebola Facts, PERSON
# Countries With Ebola, PERSON
# Doctors Without Borders, PERSON
# Ebola Crosses New Border, PERSON
# Mali Confirms, PERSON
# CaseOCT, ORGANIZATION
# No, ORGANIZATION
# Craig Spencer, PERSON
# New York, GPE
# Patient Quarantined, PERSON
# Strict New Policy, PERSON
# EbolaOCT, ORGANIZATION
# Ebola Spreads, PERSON
# So Have Several, PERSON
# Mali, GPE
# Ebola, PERSON
# Islamist, ORGANIZATION
# Mali, PERSON
# Mali, GPE
# Kissidougou, GPE
# Ebola, GPE
#
# Article
#  5
# Strict New Policy, PERSON
# Ebola By, PERSON
# MARC SANTORAOCT, ORGANIZATION
# Newark, GPE
# Ebola, PERSON
# Africa, GPE
# University Hospital, ORGANIZATION
# Credit, ORGANIZATION
# Robert Stolarik, PERSON
# New York, GPE
# Ebola, PERSON
# West Africa, LOCATION
# Newark, GPE
# New York, GPE
# New Jersey, GPE
# Ebola, ORGANIZATION
# New Jersey, GPE
# Newark Liberty International Airport, ORGANIZATION
# New Jersey Department, ORGANIZATION
# Health, PERSON
# University Hospital, ORGANIZATION
# Newark, GPE
# Andrew, PERSON
# New York, GPE
# Chris Christie, PERSON
# New Jersey, GPE
# Newark Liberty, ORGANIZATION
# Kennedy International Airport, PERSON
# Ebola, PERSON
# Guinea, GPE
# Liberia, GPE
# Sierra Leone, PERSON
# RELATED, ORGANIZATION
# While Workers Sanitize Infected, PERSON
# Outbreak, GPE
# Opens Up Public Rift With, PERSON
# Blasio, PERSON
# Mali Reports, PERSON
# West, ORGANIZATION
# Harlem, GPE
# Craig Spencer, PERSON
# Ebola, PERSON
# New York, GPE
# Ease, ORGANIZATION
# Danger, PERSON
# Start Vaccine Trials, PERSON
# West Africa, LOCATION
# Early, PERSON
# Obama, PERSON
# Nina Pham, PERSON
# Ebola, PERSON
# Oval Office, FACILITY
# Free, PERSON
# Ebola, GPE
# Makes, PERSON
# White House Detour, FACILITY
# Way HomeOCT, PERSON
# Bellevue Hospital Center, ORGANIZATION
# New, GPE
# Ebola, PERSON
# Front Line, PERSON
# Darrell Issa, PERSON
# Ebola, PERSON
# Obama, ORGANIZATION
# Steps Up Criticism, PERSON
# Ebola ResponseOCT, PERSON
# New York City, GPE
# Ebola, GPE
# Photo, PERSON
# Andrew, PERSON
# Chris Christie, PERSON
# Credit, ORGANIZATION
# Katie Orlinsky, PERSON
# New York, GPE
# Mr. Cuomo, PERSON
# Mr. Christie, PERSON
# Ebola, PERSON
# Mr. Cuomo, PERSON
# New York City, GPE
# Ebola, PERSON
# Craig Spencer, PERSON
# Bellevue Hospital Center, ORGANIZATION
# No, ORGANIZATION
# Craig Spencer, PERSON
# New York, GPE
# Credit, ORGANIZATION
# Todd, PERSON
# New York, GPE
# Kennedy International, PERSON
# Newark, GPE
# New York, GPE
# New, GPE
# Jersey, PERSON
# RELATED, ORGANIZATION
# ParadoxOCT, ORGANIZATION
# White House, FACILITY
# Photo, PERSON
# Mayor Bill, PERSON
# Blasio, PERSON
# Bassett, PERSON
# Credit, ORGANIZATION
# Josh, PERSON
# New York, GPE
# New York, GPE
# New Jersey, GPE
# West Africa, LOCATION
# United Nations, ORGANIZATION
# Ebola, PERSON
# Ebola, GPE
# Obama, PERSON
# West, GPE
# Mr. Christie, PERSON
# Republican, ORGANIZATION
# Mr. Cuomo, PERSON
# Centers, ORGANIZATION
# Disease Control, PERSON
# storyVideo, ORGANIZATION
# Keep Calm, PERSON
# Carry On Ebola, PERSON
# Keep Calm, PERSON
# Carry On, PERSON
# Ebola, PERSON
# New Yorkers, ORGANIZATION
# Video, GPE
# Stephen Farrell, PERSON
# Natalia V. Osipova, PERSON
# Publish Date, PERSON
# New York City, GPE
# Borders, GPE
# Guinea, GPE
# Ebola, GPE
# Africa, PERSON
# New York, GPE
# March, PERSON
# Doctors Without Borders, PERSON
# Ebola, ORGANIZATION
# Guinea, GPE
# Sierra Leone, PERSON
# Harlem, GPE
# storyVideo, ORGANIZATION
# New York, GPE
# Ebola Case Three Quarantined, PERSON
# New York, GPE
# Ebola Case, PERSON
# Manhattan, GPE
# Ebola, PERSON
# Publish, GPE
# Date, ORGANIZATION
# Photo, GPE
# Associated Press, ORGANIZATION
# Bill, PERSON
# Blasio, PERSON
# Brooklyn, GPE
# Manhattan, GPE
# GRAPHIC, ORGANIZATION
# New York City, GPE
# Ebola Patient Was, PERSON
# Craig Spencer, PERSON
# Manhattan, GPE
# Ebola, PERSON
# Riverside Drive, PERSON
# High Line, ORGANIZATION
# Meatball Shop, ORGANIZATION
# West Village, LOCATION
# Health, GPE
# Travis Bassett, PERSON
# Bassett, PERSON
# Africa, GPE
# LinkedIn, ORGANIZATION
# RECENT, ORGANIZATION
# COMMENTS, ORGANIZATION
# COMMENTS, ORGANIZATION
# Mr. Cuomo, PERSON
# Doctors Without Borders, PERSON
# William Schaffner, PERSON
# Vanderbilt University, ORGANIZATION
# Schaffner, PERSON
# West Africa, LOCATION
# EBOLA, ORGANIZATION
# Ebola, PERSON
# Nurse Criticizes Her Quarantine Tested Negative, PERSON
# Ebola, PERSON
# Nurse Criticizes Her Quarantine Kaci Hickox, PERSON
# New Jersey, GPE
# Ebola, PERSON
# Sierra Leone, GPE
# New York, GPE
# Bringing, GPE
# Comforting Message, ORGANIZATION
# Chaotic Time, ORGANIZATION
# New York, GPE
# Bringing, GPE
# Comforting Message, ORGANIZATION
# Chaotic Time, ORGANIZATION
# Travis Bassett, PERSON
# Ebola, ORGANIZATION
# New York, GPE
# Ebola Response, PERSON
# Opposite, ORGANIZATION
# New York, GPE
# Ebola Response, PERSON
# Opposite, ORGANIZATION
# Dallas, GPE
# Ebola, GPE
# New York, GPE
# New, GPE
# Ebola Quarantine Protocol Seen, PERSON
# Barrier, PERSON
# Volunteers New Ebola Quarantine, ORGANIZATION
# Barrier, PERSON
# Volunteers Requirements, ORGANIZATION
# Ebola, PERSON
# New York, GPE
# New Jersey, GPE
# Bassett, PERSON
# American, GPE
# Africa, GPE
# American Civil Liberties Union, ORGANIZATION
# New Jersey, GPE
# West Africa, LOCATION
# American, GPE
# West Africa, LOCATION
# Obama, PERSON
# Oval Office, FACILITY
# Nina Pham, PERSON
# Dallas, GPE
# Blasio, GPE
# Ebola, ORGANIZATION
# Morgan Dixon, PERSON
# Bellevue Hospital Center, ORGANIZATION
# CONTINUE, ORGANIZATION
# READING, ORGANIZATION
# THE, ORGANIZATION
# MAIN, ORGANIZATION
# COMMENT Health, ORGANIZATION
# Gutter, ORGANIZATION
# Twitter, PERSON
# Irwin Redlener, PERSON
# National Center, ORGANIZATION
# Disaster Preparedness, PERSON
# Columbia University, ORGANIZATION
# Blasio, PERSON
# Public, GPE
# American Civil Liberties Union, ORGANIZATION
# New Jersey, GPE
# American Civil Liberties Union, ORGANIZATION
#
# Article
#  6
# New York, GPE
# Ebola Patient Enters More Serious Phase, PERSON
# Illness, GPE
# Officials Say By, PERSON
# ANEMONA, ORGANIZATION
# Craig Spencer, PERSON
# New York, GPE
# Craig Spencer, PERSON
# Ana Marengo, PERSON
# Bellevue Hospital Center, ORGANIZATION
# Bellevue, ORGANIZATION
# Spencer, PERSON
# Ebola, PERSON
# EBOLA, ORGANIZATION
# Ebola, PERSON
# Nurse Criticizes Her Quarantine Tested Negative, PERSON
# Ebola, PERSON
# Nurse Criticizes Her Quarantine Kaci Hickox, PERSON
# New Jersey, GPE
# Ebola, PERSON
# Sierra Leone, GPE
# New York, GPE
# Bringing, GPE
# Comforting Message, ORGANIZATION
# Chaotic Time, ORGANIZATION
# New York, GPE
# Bringing, GPE
# Comforting Message, ORGANIZATION
# Chaotic Time, ORGANIZATION
# Travis Bassett, PERSON
# Ebola, ORGANIZATION
# New York, GPE
# Ebola Response, PERSON
# Opposite, ORGANIZATION
# New York, GPE
# Ebola Response, PERSON
# Opposite, ORGANIZATION
# Dallas, GPE
# Ebola, GPE
# New York, GPE
# New, GPE
# Ebola Quarantine Protocol Seen, PERSON
# Barrier, PERSON
# Volunteers New Ebola Quarantine, ORGANIZATION
# Barrier, PERSON
# Volunteers Requirements, ORGANIZATION
# Ebola, PERSON
# New York, GPE
# New Jersey, GPE
# RELATED, ORGANIZATION
# Ebola, PERSON
# West Africa, LOCATION
# University Hospital, ORGANIZATION
# Newark Liberty International Airport, ORGANIZATION
# Ebola, PERSON
# Nurse Criticizes Her, PERSON
# Ebola, PERSON
# Fiancée Shares, PERSON
# Need, GPE
# Friends Say, PERSON
# Travis Bassett, PERSON
# New York City, GPE
# Ebola, PERSON
# Emergency Management, ORGANIZATION
# Brooklyn, GPE
# Bill, PERSON
# Blasio, PERSON
# Ebola FearsOCT, PERSON
# Bellevue Hospital, ORGANIZATION
# New York, GPE
# Ebola Spread, PERSON
# Dallas, GPE
# New York, GPE
# Honed Protocol, PERSON
# Bellevue, ORGANIZATION
# Centers, ORGANIZATION
# Disease Control, PERSON
# Ebola, GPE
# Emory University Hospital, PERSON
# Nebraska Medical Center, ORGANIZATION
# Ebola, GPE
# Harlem, GPE
# High Line, ORGANIZATION
# Brooklyn, GPE
# City, GPE
# Ebola, GPE
# Bill, PERSON
# Blasio, PERSON
# Andrew, PERSON
# Mr. Cuomo, PERSON
# Mr. Cuomo, PERSON
# West Africa, LOCATION
# Mr., PERSON
# Blasio, PERSON
# Mr. Cuomo, PERSON
# Chris Christie, PERSON
# New Jersey, GPE
# Republican, ORGANIZATION
# Newark Liberty International, ORGANIZATION
# Kennedy International Airports, PERSON
# Mr., PERSON
# Blasio, PERSON
# Bassett, PERSON
# Mr., PERSON
# Blasio, PERSON
# Centers, ORGANIZATION
# Disease Control, PERSON
# Kaci Hickox, PERSON
# Newark, GPE
# Ebola, GPE
# Sierra Leone, PERSON
# U.S., GPE
# Ebola, PERSON
# NEXT, ORGANIZATION
#
# Article
#  7
# New York, GPE
# Ebola Patient Enters More Serious Phase, PERSON
# Illness, GPE
# Officials Say By, PERSON
# ANEMONA, ORGANIZATION
# Craig Spencer, PERSON
# New York, GPE
# Craig Spencer, PERSON
# Ana Marengo, PERSON
# Bellevue Hospital Center, ORGANIZATION
# Bellevue, ORGANIZATION
# Spencer, PERSON
# Ebola, PERSON
# EBOLA, ORGANIZATION
# Ebola, PERSON
# Nurse Criticizes Her Quarantine Tested Negative, PERSON
# Ebola, PERSON
# Nurse Criticizes Her Quarantine Kaci Hickox, PERSON
# New Jersey, GPE
# Ebola, PERSON
# Sierra Leone, GPE
# New York, GPE
# Bringing, GPE
# Comforting Message, ORGANIZATION
# Chaotic Time, ORGANIZATION
# New York, GPE
# Bringing, GPE
# Comforting Message, ORGANIZATION
# Chaotic Time, ORGANIZATION
# Travis Bassett, PERSON
# Ebola, ORGANIZATION
# New York, GPE
# Ebola Response, PERSON
# Opposite, ORGANIZATION
# New York, GPE
# Ebola Response, PERSON
# Opposite, ORGANIZATION
# Dallas, GPE
# Ebola, GPE
# New York, GPE
# New, GPE
# Ebola Quarantine Protocol Seen, PERSON
# Barrier, PERSON
# Volunteers New Ebola Quarantine, ORGANIZATION
# Barrier, PERSON
# Volunteers Requirements, ORGANIZATION
# Ebola, PERSON
# New York, GPE
# New Jersey, GPE
# RELATED, ORGANIZATION
# Ebola, PERSON
# West Africa, LOCATION
# University Hospital, ORGANIZATION
# Newark Liberty International Airport, ORGANIZATION
# Ebola, PERSON
# Nurse Criticizes Her, PERSON
# Ebola, PERSON
# Fiancée Shares, PERSON
# Need, GPE
# Friends Say, PERSON
# Travis Bassett, PERSON
# New York City, GPE
# Ebola, PERSON
# Emergency Management, ORGANIZATION
# Brooklyn, GPE
# Bill, PERSON
# Blasio, PERSON
# Ebola FearsOCT, PERSON
# Bellevue Hospital, ORGANIZATION
# New York, GPE
# Ebola Spread, PERSON
# Dallas, GPE
# New York, GPE
# Honed Protocol, PERSON
# Bellevue, ORGANIZATION
# Centers, ORGANIZATION
# Disease Control, PERSON
# Ebola, GPE
# Emory University Hospital, PERSON
# Nebraska Medical Center, ORGANIZATION
# Ebola, GPE
# Harlem, GPE
# High Line, ORGANIZATION
# Brooklyn, GPE
# City, GPE
# Ebola, GPE
# Bill, PERSON
# Blasio, PERSON
# Andrew, PERSON
# Mr. Cuomo, PERSON
# Mr. Cuomo, PERSON
# West Africa, LOCATION
# Mr., PERSON
# Blasio, PERSON
# Mr. Cuomo, PERSON
# Chris Christie, PERSON
# New Jersey, GPE
# Republican, ORGANIZATION
# Newark Liberty International, ORGANIZATION
# Kennedy International Airports, PERSON
# Mr., PERSON
# Blasio, PERSON
# Bassett, PERSON
# Mr., PERSON
# Blasio, PERSON
# Centers, ORGANIZATION
# Disease Control, PERSON
# Kaci Hickox, PERSON
# Newark, GPE
# Ebola, GPE
# Sierra Leone, PERSON
# U.S., GPE
# Ebola, PERSON
# NEXT, ORGANIZATION
#
# Article
#  8
# Ebola, GPE
# Chris Johnston, PERSON
# EDT Barack Obama, ORGANIZATION
# Dallas, GPE
# Ebola, GPE
# Ebola, GPE
# World, ORGANIZATION
# Organisation, PERSON
# Africa, PERSON
# Liberia, GPE
# Sierra Leone, PERSON
# WHO, ORGANIZATION
# Liberia, GPE
# Guinea, PERSON
# Ivory Coast, PERSON
# Nigeria, GPE
# Senegal, GPE
# WHO, ORGANIZATION
# Spain, GPE
# US, ORGANIZATION
# Mali, GPE
# Liberia, GPE
# Ebola, PERSON
# Guinea, GPE
# Liberia, GPE
# Nigeria, GPE
# Sierra Leone, GPE
# Spain, GPE
# Ebola, PERSON
# Africa, GPE
# Mali, GPE
# Ebola, PERSON
# WHO, ORGANIZATION
# Mali, GPE
# Guinea, GPE
# Guinea, GPE
# Mali, GPE
# WHO, ORGANIZATION
# Malian, GPE
# Mali, PERSON
# Ebola, GPE
# Guinea, PERSON
# UN, ORGANIZATION
# Mali, GPE
# New York, GPE
# New Jersey, GPE
# Ebola, PERSON
# Africa, PERSON
# Newark Liberty, ORGANIZATION

# %% [markdown]
# # Part 2.2 (Relation Extraction)

# %%
import re
IN = re.compile(r'.*\b.*\s(?:for|at|in|from).*\b(?!\b.+ing)')
for doc in nltk.corpus.ieer.parsed_docs('NYT_19980315'):
    for rel in nltk.sem.extract_rels('PER', 'ORG', doc, corpus='ieer', pattern = IN):
        print(nltk.sem.rtuple(rel))
# Out:
# [PER: u'Mike Godwin'] u', chief counsel for the' [ORG: u'Electronic Frontier Foundation']
# [PER: u'Cohn'] u', a partner in the' [ORG: u'McGlashan &AMP; Sarrail']
# [PER: u'Jack Balkin'] u", director of the school's program. ``What happened at" [ORG: u'Yale']
# [PER: u'Jones'] u'will introduce' [ORG: u'Qradio']
# [PER: u'Jones'] u', said the seed that germinated into' [ORG: u'Qradio']
# [PER: u'William Gale'] u', an economist at the' [ORG: u'Brookings Institution']
# [PER: u'Joel Slemrod'] u', an economist at the' [ORG: u'University of Michigan']
# [PER: u'Alan Braverman'] u', Internet analyst at' [ORG: u'Credit Suisse First Boston']
# [PER: u'Abe Kleinfield'] u', a vice president at' [ORG: u'Open Text']
# [PER: u'Braverman'] u'said. Success today comes from branding and distribution, and' [ORG: u'Yahoo']
# [PER: u'Rick Yorn'] u', his manager at the firm' [ORG: u'Addis-Wechsler &AMP; Associates']
# [PER: u'Tom Rothman'] u', president of production at' [ORG: u'20th Century Fox']
# [PER: u'Charlotte Forest'] u', executive producer for' [ORG: u'Homestead Editorial']
# [PER: u'Richard Strauss'] u"' ``Salome'' at" [ORG: u'La Scala']
# [PER: u'John Wren'] u', the president and chief executive at' [ORG: u'Omnicom']
# [PER: u'Lawrence'] u'withdrew from active involvement, and financial problems began to impede' [ORG: u'Wells']
# [PER: u'Linda Kaplan Thaler'] u', who worked at' [ORG: u'Wells']
# [PER: u'Kaplan Thaler'] u'had worked for' [ORG: u"Toys ``R'' Us"]
# [PER: u'Ken Haldin'] u', a spokesman for' [ORG: u'Georgia-Pacific']
